# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
os.chdir("/kaggle/input/eegdata")
# Out:
# /kaggle/input/eegdata/y_test.npy
# /kaggle/input/eegdata/main.py
# /kaggle/input/eegdata/y_train_valid.npy
# /kaggle/input/eegdata/person_train_valid.npy
# /kaggle/input/eegdata/EEG_pl.py
# /kaggle/input/eegdata/X_test.npy
# /kaggle/input/eegdata/dataset.py
# /kaggle/input/eegdata/EEG_loading.ipynb
# /kaggle/input/eegdata/person_test.npy
# /kaggle/input/eegdata/X_train_valid.npy
# /kaggle/input/eegdata/classifier.py

# %%
import numpy as np
import pandas as pd
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten,Dropout
from keras.layers import Conv2D,BatchNormalization,MaxPooling2D,Reshape, CuDNNGRU
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras import regularizers
from keras.callbacks import EarlyStopping

# %%
## Loading the numpy arrays corresponding to the EEG dataset

X_test = np.load("X_test.npy")
y_test = np.load("y_test.npy")
person_train_valid = np.load("person_train_valid.npy")
X_train_valid = np.load("X_train_valid.npy")
y_train_valid = np.load("y_train_valid.npy")
person_test = np.load("person_test.npy")

## Printing the shapes of the numpy arrays

print ('Training/Valid data shape: {}'.format(X_train_valid.shape))
print ('Test data shape: {}'.format(X_test.shape))
print ('Training/Valid target shape: {}'.format(y_train_valid.shape))
print ('Test target shape: {}'.format(y_test.shape))
print ('Person train/valid shape: {}'.format(person_train_valid.shape))
print ('Person test shape: {}'.format(person_test.shape))
# Out:
# Training/Valid data shape: (2115, 22, 1000)
# Test data shape: (443, 22, 1000)
# Training/Valid target shape: (2115,)
# Test target shape: (443,)
# Person train/valid shape: (2115, 1)
# Person test shape: (443, 1)

# %%
## Adjusting the labels to {0,1,2,3}

# Cue onset left is 769 - 0
# Cue onset right is 770 - 1
# Cue onset foot is 771 - 2
# Cue onset tongue is 772 - 3

y_train_valid -= 769
y_test -= 769

# %%
def data_prep(X,y,sub_sample,average,noise):
    
    total_X = None
    total_y = None
    
    # Trimming the data (sample,22,1000) -> (sample,22,500)
    X = X[:,:,0:500]
    print('Shape of X after trimming:',X.shape)
    
    # Maxpooling the data (sample,22,1000) -> (sample,22,500/sub_sample)
    X_max = np.max(X.reshape(X.shape[0], X.shape[1], -1, sub_sample), axis=3)
    
    
    total_X = X_max
    total_y = y
    print('Shape of X after maxpooling:',total_X.shape)
    
    # Averaging + noise 
    X_average = np.mean(X.reshape(X.shape[0], X.shape[1], -1, average),axis=3)
    X_average = X_average + np.random.normal(0.0, 0.5, X_average.shape)
    
    total_X = np.vstack((total_X, X_average))
    total_y = np.hstack((total_y, y))
    print('Shape of X after averaging+noise and concatenating:',total_X.shape)
    
    # Subsampling
    
    for i in range(sub_sample):
        
        X_subsample = X[:, :, i::sub_sample] + \
                            (np.random.normal(0.0, 0.5, X[:, :,i::sub_sample].shape) if noise else 0.0)
            
        total_X = np.vstack((total_X, X_subsample))
        total_y = np.hstack((total_y, y))
        
    
    print('Shape of X after subsampling and concatenating:',total_X.shape)
    return total_X,total_y

X_train_valid_prep,y_train_valid_prep = data_prep(X_train_valid,y_train_valid,2,2,True)
X_test_prep,y_test_prep = data_prep(X_test,y_test,2,2,True)
# Out:
# Shape of X after trimming: (2115, 22, 500)
# Shape of X after maxpooling: (2115, 22, 250)
# Shape of X after averaging+noise and concatenating: (4230, 22, 250)
# Shape of X after subsampling and concatenating: (8460, 22, 250)
# Shape of X after trimming: (443, 22, 500)
# Shape of X after maxpooling: (443, 22, 250)
# Shape of X after averaging+noise and concatenating: (886, 22, 250)
# Shape of X after subsampling and concatenating: (1772, 22, 250)

# %%
## Creating the training and validation sets

# First generating the training and validation indices using random splitting
ind_valid = np.random.choice(8460, 1500, replace=False)
ind_train = np.array(list(set(range(8460)).difference(set(ind_valid))))

# Creating the training and validation sets using the generated indices
(x_train, x_valid) = X_train_valid_prep[ind_train], X_train_valid_prep[ind_valid] 
(y_train, y_valid) = y_train_valid_prep[ind_train], y_train_valid_prep[ind_valid]
print('Shape of training set:',x_train.shape)
print('Shape of validation set:',x_valid.shape)
print('Shape of training labels:',y_train.shape)
print('Shape of validation labels:',y_valid.shape)


# Converting the labels to categorical variables for multiclass classification
y_train = to_categorical(y_train, 4)
y_valid = to_categorical(y_valid, 4)
y_test = to_categorical(y_test_prep, 4)
print('Shape of training labels after categorical conversion:',y_train.shape)
print('Shape of validation labels after categorical conversion:',y_valid.shape)
print('Shape of test labels after categorical conversion:',y_test.shape)

# Adding width of the segment to be 1
x_train = x_train.reshape(x_train.shape[0], x_train.shape[1], x_train.shape[2], 1)
x_valid = x_valid.reshape(x_valid.shape[0], x_valid.shape[1], x_train.shape[2], 1)
x_test = X_test_prep.reshape(X_test_prep.shape[0], X_test_prep.shape[1], X_test_prep.shape[2], 1)
print('Shape of training set after adding width info:',x_train.shape)
print('Shape of validation set after adding width info:',x_valid.shape)
print('Shape of test set after adding width info:',x_test.shape)


# Reshaping the training and validation dataset
x_train = np.swapaxes(x_train, 1,3)
x_train = np.swapaxes(x_train, 1,2)
x_valid = np.swapaxes(x_valid, 1,3)
x_valid = np.swapaxes(x_valid, 1,2)
x_test = np.swapaxes(x_test, 1,3)
x_test = np.swapaxes(x_test, 1,2)
print('Shape of training set after dimension reshaping:',x_train.shape)
print('Shape of validation set after dimension reshaping:',x_valid.shape)
print('Shape of test set after dimension reshaping:',x_test.shape)
# Out:
# Shape of training set: (6960, 22, 250)
# Shape of validation set: (1500, 22, 250)
# Shape of training labels: (6960,)
# Shape of validation labels: (1500,)
# Shape of training labels after categorical conversion: (6960, 4)
# Shape of validation labels after categorical conversion: (1500, 4)
# Shape of test labels after categorical conversion: (1772, 4)
# Shape of training set after adding width info: (6960, 22, 250, 1)
# Shape of validation set after adding width info: (1500, 22, 250, 1)
# Shape of test set after adding width info: (1772, 22, 250, 1)
# Shape of training set after dimension reshaping: (6960, 250, 1, 22)
# Shape of validation set after dimension reshaping: (1500, 250, 1, 22)
# Shape of test set after dimension reshaping: (1772, 250, 1, 22)

# %%
gru_model = Sequential()

gru_model.add(Flatten(input_shape=(250,1,22)))

gru_model.add(Dense((1100))) # FC layer with 100 units
gru_model.add(Reshape((1100,1))) # Reshape my output of FC layer so that it's compatible
gru_model.add(CuDNNGRU(256, input_shape=(1100,1), return_sequences=False))
gru_model.add(Dropout(0.5))

gru_model.add(Dense((220))) # FC layer with 100 units
gru_model.add(Reshape((220,1))) # Reshape my output of FC layer so that it's compatible
gru_model.add(CuDNNGRU(128, input_shape=(220,1), return_sequences=False))
gru_model.add(Dropout(0.5))

gru_model.add(Dense((44))) # FC layer with 100 units
gru_model.add(Reshape((44,1))) # Reshape my output of FC layer so that it's compatible
gru_model.add(CuDNNGRU(64, input_shape=(44,1), return_sequences=False))
gru_model.add(Dropout(0.5))


# Output layer with Softmax activation 
gru_model.add(Dense(4, activation='softmax', kernel_regularizer=regularizers.l2(0.01))) # Output FC layer with softmax activation


# Printing the model summary
gru_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 5500)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1100)              6051100
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 1100, 1)           0
# _________________________________________________________________
# cu_dnngru (CuDNNGRU)         (None, 256)               198912
# _________________________________________________________________
# dropout (Dropout)            (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 220)               56540
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 220, 1)            0
# _________________________________________________________________
# cu_dnngru_1 (CuDNNGRU)       (None, 128)               50304
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 44)                5676
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 44, 1)             0
# _________________________________________________________________
# cu_dnngru_2 (CuDNNGRU)       (None, 64)                12864
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 260
# =================================================================
# Total params: 6,375,656
# Trainable params: 6,375,656
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

#won't get validation accuracy ~0.95 when training in 200 epochs with lr=1e-4
learning_rate = 1e-3
epochs = 200
optimizer = Adam(learning_rate=learning_rate)

# %%
# Compiling the model
gru_model.compile(loss='categorical_crossentropy',
                 optimizer=optimizer,
                 metrics=['accuracy'])

callbacks = [EarlyStopping(monitor='val_accuracy', patience=25)]

# Training and validating the model
gru_results = gru_model.fit(x_train,
             y_train,
             batch_size=32,
             epochs=epochs,
             validation_data=(x_valid, y_valid), 
             callbacks=callbacks,                                             
             verbose=True)
# Out:
# 2022-03-14 06:15:45.872009: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/200
# 2022-03-14 06:15:48.811495: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 218/218 [==============================] - 22s 82ms/step - loss: 1.4074 - accuracy: 0.2783 - val_loss: 1.3580 - val_accuracy: 0.3553
# Epoch 2/200
# 218/218 [==============================] - 17s 78ms/step - loss: 1.3116 - accuracy: 0.3746 - val_loss: 1.2663 - val_accuracy: 0.4020
# Epoch 3/200
# 218/218 [==============================] - 17s 77ms/step - loss: 1.2341 - accuracy: 0.4216 - val_loss: 1.1895 - val_accuracy: 0.4447
# Epoch 4/200
# 218/218 [==============================] - 17s 78ms/step - loss: 1.1416 - accuracy: 0.4698 - val_loss: 1.1249 - val_accuracy: 0.4887
# Epoch 5/200
# 218/218 [==============================] - 17s 77ms/step - loss: 1.0680 - accuracy: 0.5185 - val_loss: 1.0543 - val_accuracy: 0.5153
# Epoch 6/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.9954 - accuracy: 0.5605 - val_loss: 1.0482 - val_accuracy: 0.5440
# Epoch 7/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.9201 - accuracy: 0.6037 - val_loss: 0.9955 - val_accuracy: 0.5727
# Epoch 8/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.8761 - accuracy: 0.6407 - val_loss: 0.9473 - val_accuracy: 0.6073
# Epoch 9/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.8390 - accuracy: 0.6609 - val_loss: 0.9491 - val_accuracy: 0.6000
# Epoch 10/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.7770 - accuracy: 0.6838 - val_loss: 0.9215 - val_accuracy: 0.6447
# Epoch 11/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.7362 - accuracy: 0.7157 - val_loss: 0.8935 - val_accuracy: 0.6540
# Epoch 12/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.7149 - accuracy: 0.7207 - val_loss: 0.8733 - val_accuracy: 0.6647
# Epoch 13/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.6718 - accuracy: 0.7422 - val_loss: 0.8514 - val_accuracy: 0.6647
# Epoch 14/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.6454 - accuracy: 0.7632 - val_loss: 0.7939 - val_accuracy: 0.6960
# Epoch 15/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.6277 - accuracy: 0.7714 - val_loss: 0.8338 - val_accuracy: 0.6880
# Epoch 16/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.5972 - accuracy: 0.7848 - val_loss: 0.7968 - val_accuracy: 0.7080
# Epoch 17/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.5659 - accuracy: 0.7944 - val_loss: 0.7991 - val_accuracy: 0.7067
# Epoch 18/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.5417 - accuracy: 0.8128 - val_loss: 0.7702 - val_accuracy: 0.7213
# Epoch 19/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.5437 - accuracy: 0.8115 - val_loss: 0.7343 - val_accuracy: 0.7373
# Epoch 20/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.5274 - accuracy: 0.8170 - val_loss: 0.7435 - val_accuracy: 0.7220
# Epoch 21/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.5147 - accuracy: 0.8223 - val_loss: 0.7429 - val_accuracy: 0.7340
# Epoch 22/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.5033 - accuracy: 0.8295 - val_loss: 0.7220 - val_accuracy: 0.7353
# Epoch 23/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.4595 - accuracy: 0.8407 - val_loss: 0.7866 - val_accuracy: 0.7293
# Epoch 24/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.4757 - accuracy: 0.8365 - val_loss: 0.7273 - val_accuracy: 0.7473
# Epoch 25/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.4647 - accuracy: 0.8415 - val_loss: 0.8213 - val_accuracy: 0.7227
# Epoch 26/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.4466 - accuracy: 0.8510 - val_loss: 0.7076 - val_accuracy: 0.7553
# Epoch 27/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.4337 - accuracy: 0.8514 - val_loss: 0.7339 - val_accuracy: 0.7527
# Epoch 28/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.4252 - accuracy: 0.8580 - val_loss: 0.7577 - val_accuracy: 0.7527
# Epoch 29/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.4003 - accuracy: 0.8763 - val_loss: 0.7485 - val_accuracy: 0.7513
# Epoch 30/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.4050 - accuracy: 0.8730 - val_loss: 0.7377 - val_accuracy: 0.7680
# Epoch 31/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3951 - accuracy: 0.8772 - val_loss: 0.6948 - val_accuracy: 0.7687
# Epoch 32/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3809 - accuracy: 0.8773 - val_loss: 0.6922 - val_accuracy: 0.7780
# Epoch 33/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3899 - accuracy: 0.8759 - val_loss: 0.6910 - val_accuracy: 0.7740
# Epoch 34/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3817 - accuracy: 0.8809 - val_loss: 0.6960 - val_accuracy: 0.7827
# Epoch 35/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3762 - accuracy: 0.8803 - val_loss: 0.6504 - val_accuracy: 0.7940
# Epoch 36/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3574 - accuracy: 0.8875 - val_loss: 0.6741 - val_accuracy: 0.7640
# Epoch 37/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3673 - accuracy: 0.8912 - val_loss: 0.6586 - val_accuracy: 0.7873
# Epoch 38/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3449 - accuracy: 0.8938 - val_loss: 0.6525 - val_accuracy: 0.7927
# Epoch 39/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3480 - accuracy: 0.8915 - val_loss: 0.7081 - val_accuracy: 0.7753
# Epoch 40/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3350 - accuracy: 0.9006 - val_loss: 0.7028 - val_accuracy: 0.7753
# Epoch 41/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3495 - accuracy: 0.8935 - val_loss: 0.6882 - val_accuracy: 0.7773
# Epoch 42/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3481 - accuracy: 0.8918 - val_loss: 0.6485 - val_accuracy: 0.7973
# Epoch 43/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3311 - accuracy: 0.9007 - val_loss: 0.6182 - val_accuracy: 0.7940
# Epoch 44/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3382 - accuracy: 0.8958 - val_loss: 0.6881 - val_accuracy: 0.7887
# Epoch 45/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3312 - accuracy: 0.9003 - val_loss: 0.6878 - val_accuracy: 0.7673
# Epoch 46/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3214 - accuracy: 0.9059 - val_loss: 0.6302 - val_accuracy: 0.8160
# Epoch 47/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3040 - accuracy: 0.9118 - val_loss: 0.6484 - val_accuracy: 0.7967
# Epoch 48/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3075 - accuracy: 0.9049 - val_loss: 0.6710 - val_accuracy: 0.7967
# Epoch 49/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3072 - accuracy: 0.9145 - val_loss: 0.7196 - val_accuracy: 0.7827
# Epoch 50/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3230 - accuracy: 0.9050 - val_loss: 0.6492 - val_accuracy: 0.7853
# Epoch 51/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3133 - accuracy: 0.9093 - val_loss: 0.6867 - val_accuracy: 0.7973
# Epoch 52/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.3105 - accuracy: 0.9079 - val_loss: 0.6820 - val_accuracy: 0.8033
# Epoch 53/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3057 - accuracy: 0.9072 - val_loss: 0.6969 - val_accuracy: 0.7993
# Epoch 54/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.3018 - accuracy: 0.9114 - val_loss: 0.6531 - val_accuracy: 0.7913
# Epoch 55/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.3111 - accuracy: 0.9079 - val_loss: 0.6374 - val_accuracy: 0.8113
# Epoch 56/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2924 - accuracy: 0.9168 - val_loss: 0.6371 - val_accuracy: 0.8020
# Epoch 57/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.2829 - accuracy: 0.9175 - val_loss: 0.6694 - val_accuracy: 0.8113
# Epoch 58/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2946 - accuracy: 0.9147 - val_loss: 0.6440 - val_accuracy: 0.8060
# Epoch 59/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.2906 - accuracy: 0.9124 - val_loss: 0.5720 - val_accuracy: 0.8293
# Epoch 60/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2992 - accuracy: 0.9124 - val_loss: 0.6197 - val_accuracy: 0.8040
# Epoch 61/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.2975 - accuracy: 0.9125 - val_loss: 0.6443 - val_accuracy: 0.7927
# Epoch 62/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.3031 - accuracy: 0.9046 - val_loss: 0.6504 - val_accuracy: 0.7973
# Epoch 63/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.2977 - accuracy: 0.9148 - val_loss: 0.6739 - val_accuracy: 0.7940
# Epoch 64/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2767 - accuracy: 0.9193 - val_loss: 0.6346 - val_accuracy: 0.8187
# Epoch 65/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.2941 - accuracy: 0.9119 - val_loss: 0.6372 - val_accuracy: 0.7967
# Epoch 66/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2791 - accuracy: 0.9164 - val_loss: 0.6165 - val_accuracy: 0.8147
# Epoch 67/200
# 218/218 [==============================] - 17s 77ms/step - loss: 0.2780 - accuracy: 0.9184 - val_loss: 0.5934 - val_accuracy: 0.8260
# Epoch 68/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2816 - accuracy: 0.9174 - val_loss: 0.6312 - val_accuracy: 0.8147
# Epoch 69/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2453 - accuracy: 0.9302 - val_loss: 0.6113 - val_accuracy: 0.8253
# Epoch 70/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2432 - accuracy: 0.9296 - val_loss: 0.6984 - val_accuracy: 0.7933
# Epoch 71/200
# 218/218 [==============================] - 17s 78ms/step - loss: 0.2548 - accuracy: 0.9279 - val_loss: 0.6343 - val_accuracy: 0.8180
# Epoch 72/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2522 - accuracy: 0.9297 - val_loss: 0.6799 - val_accuracy: 0.8160
# Epoch 73/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2446 - accuracy: 0.9326 - val_loss: 0.6400 - val_accuracy: 0.8160
# Epoch 74/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2265 - accuracy: 0.9366 - val_loss: 0.6583 - val_accuracy: 0.8107
# Epoch 75/200
# 218/218 [==============================] - 18s 82ms/step - loss: 0.2817 - accuracy: 0.9165 - val_loss: 0.6248 - val_accuracy: 0.8093
# Epoch 76/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2512 - accuracy: 0.9316 - val_loss: 0.6695 - val_accuracy: 0.8100
# Epoch 77/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2504 - accuracy: 0.9290 - val_loss: 0.6436 - val_accuracy: 0.8027
# Epoch 78/200
# 218/218 [==============================] - 18s 81ms/step - loss: 0.2629 - accuracy: 0.9241 - val_loss: 0.6486 - val_accuracy: 0.8120
# Epoch 79/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2646 - accuracy: 0.9241 - val_loss: 0.5768 - val_accuracy: 0.8373
# Epoch 80/200
# 218/218 [==============================] - 18s 82ms/step - loss: 0.2466 - accuracy: 0.9309 - val_loss: 0.6380 - val_accuracy: 0.8053
# Epoch 81/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2616 - accuracy: 0.9241 - val_loss: 0.6402 - val_accuracy: 0.8247
# Epoch 82/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2569 - accuracy: 0.9250 - val_loss: 0.6385 - val_accuracy: 0.8093
# Epoch 83/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2388 - accuracy: 0.9319 - val_loss: 0.6638 - val_accuracy: 0.8140
# Epoch 84/200
# 218/218 [==============================] - 18s 80ms/step - loss: 0.2460 - accuracy: 0.9287 - val_loss: 0.6206 - val_accuracy: 0.8300
# Epoch 85/200
# 218/218 [==============================] - 18s 81ms/step - loss: 0.2432 - accuracy: 0.9341 - val_loss: 0.7093 - val_accuracy: 0.7887
# Epoch 86/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2706 - accuracy: 0.9191 - val_loss: 0.6245 - val_accuracy: 0.8093
# Epoch 87/200
# 218/218 [==============================] - 18s 80ms/step - loss: 0.2507 - accuracy: 0.9286 - val_loss: 0.6770 - val_accuracy: 0.7933
# Epoch 88/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2753 - accuracy: 0.9184 - val_loss: 0.6645 - val_accuracy: 0.8067
# Epoch 89/200
# 218/218 [==============================] - 18s 83ms/step - loss: 0.2419 - accuracy: 0.9322 - val_loss: 0.6978 - val_accuracy: 0.8047
# Epoch 90/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2373 - accuracy: 0.9339 - val_loss: 0.6327 - val_accuracy: 0.8193
# Epoch 91/200
# 218/218 [==============================] - 19s 86ms/step - loss: 0.2712 - accuracy: 0.9217 - val_loss: 0.6784 - val_accuracy: 0.7960
# Epoch 92/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2594 - accuracy: 0.9240 - val_loss: 0.6296 - val_accuracy: 0.8193
# Epoch 93/200
# 218/218 [==============================] - 18s 81ms/step - loss: 0.2537 - accuracy: 0.9295 - val_loss: 0.5917 - val_accuracy: 0.8167
# Epoch 94/200
# 218/218 [==============================] - 18s 82ms/step - loss: 0.2664 - accuracy: 0.9250 - val_loss: 0.6149 - val_accuracy: 0.8207
# Epoch 95/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2428 - accuracy: 0.9351 - val_loss: 0.6252 - val_accuracy: 0.8160
# Epoch 96/200
# 218/218 [==============================] - 18s 80ms/step - loss: 0.2473 - accuracy: 0.9320 - val_loss: 0.5601 - val_accuracy: 0.8313
# Epoch 97/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2209 - accuracy: 0.9372 - val_loss: 0.6667 - val_accuracy: 0.8167
# Epoch 98/200
# 218/218 [==============================] - 18s 80ms/step - loss: 0.2351 - accuracy: 0.9329 - val_loss: 0.6419 - val_accuracy: 0.8193
# Epoch 99/200
# 218/218 [==============================] - 18s 82ms/step - loss: 0.2364 - accuracy: 0.9329 - val_loss: 0.5807 - val_accuracy: 0.8353
# Epoch 100/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2284 - accuracy: 0.9362 - val_loss: 0.6112 - val_accuracy: 0.8267
# Epoch 101/200
# 218/218 [==============================] - 17s 79ms/step - loss: 0.2351 - accuracy: 0.9359 - val_loss: 0.6256 - val_accuracy: 0.8253
# Epoch 102/200
# 218/218 [==============================] - 18s 80ms/step - loss: 0.2376 - accuracy: 0.9335 - val_loss: 0.6055 - val_accuracy: 0.8287
# Epoch 103/200
# 218/218 [==============================] - 17s 80ms/step - loss: 0.2187 - accuracy: 0.9427 - val_loss: 0.6140 - val_accuracy: 0.8300
# Epoch 104/200
# 218/218 [==============================] - 18s 82ms/step - loss: 0.2353 - accuracy: 0.9313 - val_loss: 0.6471 - val_accuracy: 0.8073

# %%
import matplotlib.pyplot as plt

# Plotting accuracy trajectory
plt.plot(gru_results.history['accuracy'])
plt.plot(gru_results.history['val_accuracy'])
plt.title('GRU model accuracy trajectory')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plotting loss trajectory
plt.plot(gru_results.history['loss'],'o')
plt.plot(gru_results.history['val_loss'],'o')
plt.title('GRU model loss trajectory')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
## Testing the hybrid CNN-LSTM model

gru_score = gru_model.evaluate(x_test, y_test, verbose=0)
print('Test accuracy of the GRU model:',gru_score[1])
# Out:
# Test accuracy of the GRU model: 0.3549661338329315

# %%
from sklearn import metrics
from sklearn.metrics import classification_report

y_pred_test = gru_model.predict(x_test)


# classification_report
for i,x in enumerate(['left','right','foot','tongue']):
    print(x)
    y_pred = np.where(y_pred_test[:,i]>0.5,1,0)
    
    print(classification_report(y_test[:,i], y_pred))
# Out:
# left
#               precision    recall  f1-score   support
#
#          0.0       0.77      0.76      0.76      1328
#          1.0       0.30      0.31      0.30       444
#
#     accuracy                           0.65      1772
#    macro avg       0.53      0.53      0.53      1772
# weighted avg       0.65      0.65      0.65      1772
#
# right
#               precision    recall  f1-score   support
#
#          0.0       0.73      0.62      0.67      1264
#          1.0       0.31      0.42      0.36       508
#
#     accuracy                           0.57      1772
#    macro avg       0.52      0.52      0.51      1772
# weighted avg       0.61      0.57      0.58      1772
#
# foot
#               precision    recall  f1-score   support
#
#          0.0       0.81      0.91      0.86      1388
#          1.0       0.41      0.23      0.30       384
#
#     accuracy                           0.76      1772
#    macro avg       0.61      0.57      0.58      1772
# weighted avg       0.72      0.76      0.73      1772
#
# tongue
#               precision    recall  f1-score   support
#
#          0.0       0.82      0.85      0.83      1336
#          1.0       0.47      0.42      0.44       436
#
#     accuracy                           0.74      1772
#    macro avg       0.64      0.63      0.64      1772
# weighted avg       0.73      0.74      0.73      1772

# %%
import tensorflow as tf

os.chdir("/kaggle/working")
tf.keras.utils.plot_model(gru_model)
